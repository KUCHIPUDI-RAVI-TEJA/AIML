# %%
print('Hello World')
# Out:
# Hello World

# %%
name = 'Ravi Teja'
print(f'My Name is: {name}')
# Out:
# My Name is: Ravi Teja

# %% [markdown]
# Variables:
# 1. In other languages we will explicitly specify data type.
# 2. But in python we no neeed to put data
# 3. All these variables stored in some address in RAM
#     To know the address we will use id() method

# %%
name = 'Ravi Teja'
standard = 10
height = 5.11

print(f'{type(name), type(standard), type(height)}')
# Out:
# (<class 'str'>, <class 'int'>, <class 'float'>)

# %%
name = 'Ravi Teja'
name = 10

print(f'{name}, Type: {type(name)}')
# Out:
# 10, Type: <class 'int'>

# %% [markdown]
# 1. All these variables stored in some address in RAM
#     To know the address we will use id() method
#
# 2. If Variables has same value, then variables will point to Same address

# %%
a = 10
b = 10

print(id(a))
print(id(b))
# Out:
# 140732014626200
# 140732014626200

# %% [markdown]
# Variable Naming Conventions:
# 1. Start with letter or _
# 2. Case sensitive (Every letter and Every Case Should Match)
# 3. No python keyword are allowed (Ex: Class, If, Else etc.,)

# %%
@name = 'Ravi'
# Out:
#   Cell In[12], line 1
#     @name = 'Ravi'
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
name = 'Ravi' 
_name = 'Teja'

# %% [markdown]
# Data Types
# Nuemeric: Integer, float,
# Text: String
# Boolean: True,False / o,1

# %% [markdown]
# Basic Maths
# Addition: +
# Subtraction: -
# Mutiplication: *
# Dividion: /
# Floor Division: //
# Remainder: %
# Power: **

# %%
print(5+3)
print(5-3)
print(5*3)
print(5/3) #Always gives a float value
print(5//3) #Always give Integer value
print(5**3)
# Out:
# 8
# 2
# 15
# 1.6666666666666667
# 1
# 125

# %%
print(10/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print(10/0)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# print() and input() functions

# %% [markdown]
# print(): What ever we put inside this method, that data will get printed

# %%
print("wewe")
print(10)
# Out:
# wewe
# 10
